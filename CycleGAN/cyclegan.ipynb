# %% [markdown]
# #Code Setup

# %%
    # !pip install torch
# !pip install torchvision
# !pip install dominate
# !pip install pytorch-fid
# Out:
# ...
#   Created wheel for pytorch-fid: filename=pytorch_fid-0.2.0-cp37-none-any.whl size=10547 sha256=9b45aeaa5115bde0820df3f8e772452736af4d7ff7b25371688f5224a9c50a6d
#   Stored in directory: /root/.cache/pip/wheels/72/36/3c/4f3fb256f62d24bef52636f66f21667bc21caa637ce92f0e53
# Successfully built pytorch-fid
# ...

# %%
# !git clone https://github.com/XkunW/Image_Translation.git
# Out:
# Cloning into 'Image_Translation'...
# remote: Enumerating objects: 89, done.
# remote: Counting objects: 100% (89/89), done.
# remote: Compressing objects: 100% (66/66), done.
# remote: Total 381 (delta 50), reused 53 (delta 23), pack-reused 292
# Receiving objects: 100% (381/381), 382.56 MiB | 40.10 MiB/s, done.
# Resolving deltas: 100% (159/159), done.

# %% [markdown]
# #Mount Drive

# %%
# Mount drive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
data_dir = '/content/drive/MyDrive/CSC2516_Project/Datasets/'
# Out:
# Mounted at /content/drive

# %%
# data zip 
summer2winter = data_dir+'summer2winter_yosemite_small_dataset.zip'
monet2photo = data_dir+'monet2photo_small_dataset.zip'
# Unzipping datasets to the target folder
# !unzip "$summer2winter" -d '/content/Image_Translation/CycleGAN/datasets/'
# !unzip "$monet2photo" -d '/content/Image_Translation/CycleGAN/datasets/'
# Out:
# Archive:  /content/drive/MyDrive/CSC2516_Project/Datasets/summer2winter_yosemite_small_dataset.zip
#    creating: /content/Image_Translation/CycleGAN/datasets/summer2winter_yosemite/testA/
#   inflating: /content/Image_Translation/CycleGAN/datasets/summer2winter_yosemite/testA/2010-09-07 12_23_20.jpg
#   inflating: /content/Image_Translation/CycleGAN/datasets/summer2winter_yosemite/testA/2010-10-05 13_45_11.jpg
#   inflating: /content/Image_Translation/CycleGAN/datasets/summer2winter_yosemite/testA/2010-10-05 19_08_31.jpg
#   inflating: /content/Image_Translation/CycleGAN/datasets/summer2winter_yosemite/testA/2011-05-23 17_46_40.jpg
#   inflating: /content/Image_Translation/CycleGAN/datasets/summer2winter_yosemite/testA/2011-05-26 15_06_01.jpg
#   inflating: /content/Image_Translation/CycleGAN/datasets/summer2winter_yosemite/testA/2011-05-28 15_13_21.jpg
#   inflating: /content/Image_Translation/CycleGAN/datasets/summer2winter_yosemite/testA/2011-05-29 10_20_21.jpg
# ...

# %% [markdown]
# #Training

# %%
# !python Image_Translation/CycleGAN/train.py --dataroot ./datasets/summer2winter_yosemite --name s2w_cyclegan_lr_2_poolsize_50 --model cycle_gan --gpu_ids 0 --colab
#pool size= 50
# lr = 0.0002
# Out:
# /content/Image_Translation/CycleGAN
# ----------------- Options ---------------
#                batch_size: 1
#                     beta1: 0.5
#           checkpoints_dir: ./checkpoints
#                     colab: True                          	[default: False]
#            continue_train: False
#                 crop_size: 256
#                  dataroot: ./datasets/summer2winter_yosemite	[default: None]
#              dataset_mode: unaligned
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#               epoch_count: 1
#                  gan_mode: lsgan
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: True                          	[default: None]
#                  lambda_A: 10.0
#                  lambda_B: 10.0
#           lambda_identity: 0.5
# ...

# %%
# !python Image_Translation/CycleGAN/test.py --dataroot ./datasets/summer2winter_yosemite --name s2w_cyclegan_lr_2_poolsize_50 --model cycle_gan --colab
# Out:
# /content/Image_Translation/CycleGAN
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: ./checkpoints
#                     colab: True                          	[default: False]
#                 crop_size: 256
#                  dataroot: ./datasets/summer2winter_yosemite	[default: None]
#              dataset_mode: unaligned
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 256
#          max_dataset_size: inf
#                     model: cycle_gan                     	[default: test]
# ...

# %%
# !python Image_Translation/CycleGAN/train.py --dataroot ./datasets/summer2winter_yosemite --name s2w_cyclegan_lr_2_poolsize_100 --model cycle_gan --gpu_ids 0 --colab --pool_size 100
#pool size = 100
#lr = 0.0002
# Out:
# /content/Image_Translation/CycleGAN
# ----------------- Options ---------------
#                batch_size: 1
#                     beta1: 0.5
#           checkpoints_dir: ./checkpoints
#                     colab: True                          	[default: False]
#            continue_train: False
#                 crop_size: 256
#                  dataroot: ./datasets/summer2winter_yosemite	[default: None]
#              dataset_mode: unaligned
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#               epoch_count: 1
#                  gan_mode: lsgan
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: True                          	[default: None]
#                  lambda_A: 10.0
#                  lambda_B: 10.0
#           lambda_identity: 0.5
# ...

# %%
# !python Image_Translation/CycleGAN/test.py --dataroot ./datasets/summer2winter_yosemite --name s2w_cyclegan_lr_2_poolsize_100 --model cycle_gan --colab
# Out:
# /content/Image_Translation/CycleGAN
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: ./checkpoints
#                     colab: True                          	[default: False]
#                 crop_size: 256
#                  dataroot: ./datasets/summer2winter_yosemite	[default: None]
#              dataset_mode: unaligned
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 256
#          max_dataset_size: inf
#                     model: cycle_gan                     	[default: test]
# ...

# %%
# !python Image_Translation/CycleGAN/train.py --dataroot ./datasets/summer2winter_yosemite --name s2w_cyclegan_lr_5_poolsize_50 --model cycle_gan --gpu_ids 0 --colab --lr 0.0005 
#pool size = 50
#lr = 0.0005
# Out:
# /content/Image_Translation/CycleGAN
# ----------------- Options ---------------
#                batch_size: 1
#                     beta1: 0.5
#           checkpoints_dir: ./checkpoints
#                     colab: True                          	[default: False]
#            continue_train: False
#                 crop_size: 256
#                  dataroot: ./datasets/summer2winter_yosemite	[default: None]
#              dataset_mode: unaligned
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#               epoch_count: 1
#                  gan_mode: lsgan
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: True                          	[default: None]
#                  lambda_A: 10.0
#                  lambda_B: 10.0
#           lambda_identity: 0.5
# ...

# %%
# !python Image_Translation/CycleGAN/test.py --dataroot ./datasets/summer2winter_yosemite --name s2w_cyclegan_lr_5_poolsize_50 --model cycle_gan --colab
# Out:
# /content/Image_Translation/CycleGAN
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: ./checkpoints
#                     colab: True                          	[default: False]
#                 crop_size: 256
#                  dataroot: ./datasets/summer2winter_yosemite	[default: None]
#              dataset_mode: unaligned
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 256
#          max_dataset_size: inf
#                     model: cycle_gan                     	[default: test]
# ...

# %%
# !python Image_Translation/CycleGAN/train.py --dataroot ./datasets/summer2winter_yosemite --name s2w_cyclegan_lr_5_poolsize_100 --model cycle_gan --gpu_ids 0 --colab --lr 0.0005 --pool_size 100
#pool size = 100
#lr = 0.0005
# Out:
# /content/Image_Translation/CycleGAN
# ----------------- Options ---------------
#                batch_size: 1
#                     beta1: 0.5
#           checkpoints_dir: ./checkpoints
#                     colab: True                          	[default: False]
#            continue_train: False
#                 crop_size: 256
#                  dataroot: ./datasets/summer2winter_yosemite	[default: None]
#              dataset_mode: unaligned
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#               epoch_count: 1
#                  gan_mode: lsgan
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: True                          	[default: None]
#                  lambda_A: 10.0
#                  lambda_B: 10.0
#           lambda_identity: 0.5
# ...

# %%
# !python Image_Translation/CycleGAN/test.py --dataroot ./datasets/summer2winter_yosemite --name s2w_cyclegan_lr_5_poolsize_100 --model cycle_gan --colab
# Out:
# /content/Image_Translation/CycleGAN
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: ./checkpoints
#                     colab: True                          	[default: False]
#                 crop_size: 256
#                  dataroot: ./datasets/summer2winter_yosemite	[default: None]
#              dataset_mode: unaligned
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 256
#          max_dataset_size: inf
#                     model: cycle_gan                     	[default: test]
# ...

# %% [markdown]
# Calculate FID score

# %%
# !python -m pytorch_fid Image_Translation/CycleGAN/datasets/monet2photo/testB drive/MyDrive/results/m2p_cyclegan_lr_5_poolsize_100/fake_B
#A2B
# Out:
# 100% 2/2 [00:00<00:00,  3.39it/s]
# 100% 1/1 [00:00<00:00,  1.79it/s]
# FID:  190.00722665843028

# %%
# !python -m pytorch_fid Image_Translation/CycleGAN/datasets/monet2photo/testA drive/MyDrive/results/m2p_cyclegan_lr_5_poolsize_100/rec_A
#A2B2A
# Out:
# 100% 2/2 [00:00<00:00,  3.49it/s]
# 100% 1/1 [00:00<00:00,  1.90it/s]
# FID:  130.87174538240586

# %%
# !python -m pytorch_fid Image_Translation/CycleGAN/datasets/monet2photo/testA drive/MyDrive/results/m2p_cyclegan_lr_5_poolsize_100/fake_A
#B2A
# Out:
# 100% 2/2 [00:00<00:00,  3.53it/s]
# 100% 1/1 [00:00<00:00,  1.89it/s]
# FID:  198.10310304841667

# %%
# !python -m pytorch_fid Image_Translation/CycleGAN/datasets/monet2photo/testB drive/MyDrive/results/m2p_cyclegan_lr_5_poolsize_100/rec_B
#B2A2B
# Out:
# 100% 2/2 [00:00<00:00,  3.48it/s]
# 100% 1/1 [00:00<00:00,  1.92it/s]
# FID:  137.45033601861218
